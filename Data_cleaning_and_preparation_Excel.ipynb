# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("/content/ppml excel 07 bt (2).xlsx")
print(df)
# Out:
# Original data:
#
#    roll no     Name  English  tamil  maths  science  social   Total
# 0      101    Deepa     50.0     67   50.0       70       45    282
# 1      102   Dinesh     56.0     89   56.0       76       56    333
# 2      103   Kaviya     80.0     80   56.0       74       56    346
# 3      104  Racheal     89.0     87   67.0       64       67    374
# 4      105    Rajan      NaN     98   78.0       65       65    350
# 5      106    Ramya     67.0     76   89.0       45       56    333
# 6      107    Rohan     56.0     67   90.0       65       45    323
# 7      108   Rohini     57.0     65   54.0       78       57    311
# 8      109  Sandhya     58.0     56   32.0       89       76    311
# 9      110  Saranya     49.0     45    NaN       90       65    290

# %%
f=df['Name'].str.strip()
f.to_excel("/content/dcap.xlsx")

print("\nReplace value:")
k=df.fillna(method='pad')
print(k)
print("\nUpdated list\n")
k.to_excel("/content/dcap.xlsx")
# Out:
# Replace value:
#    roll no     Name  English  tamil  maths  science  social   Total
# 0      101    Deepa     50.0     67   50.0       70       45    282
# 1      102   Dinesh     56.0     89   56.0       76       56    333
# 2      103   Kaviya     80.0     80   56.0       74       56    346
# 3      104  Racheal     89.0     87   67.0       64       67    374
# 4      105    Rajan     89.0     98   78.0       65       65    350
# 5      106    Ramya     67.0     76   89.0       45       56    333
# 6      107    Rohan     56.0     67   90.0       65       45    323
# 7      108   Rohini     57.0     65   54.0       78       57    311
# 8      109  Sandhya     58.0     56   32.0       89       76    311
# 9      110  Saranya     49.0     45   32.0       90       65    290
#
# Updated list
# /tmp/ipykernel_152/3355944213.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   k=df.fillna(method='pad')

# %%
print("\nDrop one particular column and its values:\n")
k.drop(['social'],axis=1,inplace=True, errors='ignore')
print(k)
print("\nUpdated list..\n")
k.to_excel("/content/dcap.xlsx")
# Out:
# Drop one particular column and its values:
#
#    roll no     Name  English  tamil  maths  science  social   Total
# 0      101    Deepa     50.0     67   50.0       70       45    282
# 1      102   Dinesh     56.0     89   56.0       76       56    333
# 2      103   Kaviya     80.0     80   56.0       74       56    346
# 3      104  Racheal     89.0     87   67.0       64       67    374
# 4      105    Rajan     89.0     98   78.0       65       65    350
# 5      106    Ramya     67.0     76   89.0       45       56    333
# 6      107    Rohan     56.0     67   90.0       65       45    323
# 7      108   Rohini     57.0     65   54.0       78       57    311
# 8      109  Sandhya     58.0     56   32.0       89       76    311
# 9      110  Saranya     49.0     45   32.0       90       65    290
#
# Updated list..

# %%
print("\nDrop NaN rows:\n")
df=pd.read_excel("/content/dcap.xlsx")
print(df)
x=df.dropna()
print(x)
print("\nUpdated data list:\n")
x.to_excel("/content/dcap.xlsx")
# Out:
# Drop NaN rows:
#
#    Unnamed: 0  roll no     Name  English  tamil  maths  science  social   \
# 0           0      101    Deepa       50     67     50       70       45
# 1           1      102   Dinesh       56     89     56       76       56
# 2           2      103   Kaviya       80     80     56       74       56
# 3           3      104  Racheal       89     87     67       64       67
# 4           4      105    Rajan       89     98     78       65       65
# 5           5      106    Ramya       67     76     89       45       56
# 6           6      107    Rohan       56     67     90       65       45
# 7           7      108   Rohini       57     65     54       78       57
# 8           8      109  Sandhya       58     56     32       89       76
# 9           9      110  Saranya       49     45     32       90       65
#
#    Total
# 0    282
# 1    333
# 2    346
# 3    374
# 4    350
# 5    333
# 6    323
# 7    311
# 8    311
# 9    290
#    Unnamed: 0  roll no     Name  English  tamil  maths  science  social   \
# 0           0      101    Deepa       50     67     50       70       45
# 1           1      102   Dinesh       56     89     56       76       56
# 2           2      103   Kaviya       80     80     56       74       56
# 3           3      104  Racheal       89     87     67       64       67
# 4           4      105    Rajan       89     98     78       65       65
# 5           5      106    Ramya       67     76     89       45       56
# 6           6      107    Rohan       56     67     90       65       45
# 7           7      108   Rohini       57     65     54       78       57
# 8           8      109  Sandhya       58     56     32       89       76
# 9           9      110  Saranya       49     45     32       90       65
#
#    Total
# 0    282
# 1    333
# 2    346
# 3    374
# 4    350
# 5    333
# 6    323
# 7    311
# 8    311
# 9    290
#
# Updated data list:

# %%
print("\nReplace values:\n")
n=pd.read_excel("/content/dcap.xlsx")
print("\nOriginal data:\n")
print(n)
y=n.replace({89:88})
print("\nReplaced dataset:\n")
print(y)
print("\nUpdated dataset:\n")
y.to_excel("/content/dcap.xlsx")
# Out:
# Replace values:
#
#
# Original data:
#
#    Unnamed: 0.1  Unnamed: 0  roll no     Name  English  tamil  maths  science  \
# 0             0           0      101    Deepa       50     67     50       70
# 1             1           1      102   Dinesh       56     89     56       76
# 2             2           2      103   Kaviya       80     80     56       74
# 3             3           3      104  Racheal       89     87     67       64
# 4             4           4      105    Rajan       89     98     78       65
# 5             5           5      106    Ramya       67     76     89       45
# 6             6           6      107    Rohan       56     67     90       65
# 7             7           7      108   Rohini       57     65     54       78
# 8             8           8      109  Sandhya       58     56     32       89
# 9             9           9      110  Saranya       49     45     32       90
#
#    social   Total
# 0       45    282
# 1       56    333
# 2       56    346
# 3       67    374
# 4       65    350
# 5       56    333
# 6       45    323
# 7       57    311
# 8       76    311
# 9       65    290
#
# Replaced dataset:
#
#    Unnamed: 0.1  Unnamed: 0  roll no     Name  English  tamil  maths  science  \
# 0             0           0      101    Deepa       50     67     50       70
# 1             1           1      102   Dinesh       56     88     56       76
# 2             2           2      103   Kaviya       80     80     56       74
# 3             3           3      104  Racheal       88     87     67       64
# 4             4           4      105    Rajan       88     98     78       65
# 5             5           5      106    Ramya       67     76     88       45
# 6             6           6      107    Rohan       56     67     90       65
# 7             7           7      108   Rohini       57     65     54       78
# 8             8           8      109  Sandhya       58     56     32       88
# 9             9           9      110  Saranya       49     45     32       90
#
#    social   Total
# 0       45    282
# 1       56    333
# 2       56    346
# 3       67    374
# 4       65    350
# 5       56    333
# 6       45    323
# 7       57    311
# 8       76    311
# 9       65    290
#
# Updated dataset:

# %%
df=pd.read_excel("/content/dcap.xlsx")
print(df)
print("\nExtract using isin() function:\n")
new=df['English'].isin([88])
print(df[new])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  roll no     Name  ...  tamil  \
# 0             0             0           0      101    Deepa  ...     67
# 1             1             1           1      102   Dinesh  ...     88
# 2             2             2           2      103   Kaviya  ...     80
# 3             3             3           3      104  Racheal  ...     87
# 4             4             4           4      105    Rajan  ...     98
# 5             5             5           5      106    Ramya  ...     76
# 6             6             6           6      107    Rohan  ...     67
# 7             7             7           7      108   Rohini  ...     65
# 8             8             8           8      109  Sandhya  ...     56
# 9             9             9           9      110  Saranya  ...     45
#
#    maths  science  social   Total
# 0     50       70       45    282
# 1     56       76       56    333
# 2     56       74       56    346
# 3     67       64       67    374
# 4     78       65       65    350
# 5     88       45       56    333
# 6     90       65       45    323
# 7     54       78       57    311
# 8     32       88       76    311
# 9     32       90       65    290
#
# [10 rows x 11 columns]
#
# Extract using isin() function:
#
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  roll no     Name  ...  tamil  \
# 3             3             3           3      104  Racheal  ...     87
# 4             4             4           4      105    Rajan  ...     98
#
#    maths  science  social   Total
# 3     67       64       67    374
# 4     78       65       65    350
#
# [2 rows x 11 columns]
